# %% [markdown]
# # IPFS Data Analytics Competition Submission
# ## BI & Data Visualization
# ### Eric VanMeerhaeghe, Michael Gagliano, Zachary Bergquist, James Liem

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ## Defining A Function to Save Figures

# %%
# Where to save the figures

import os

PROJECT_ROOT_DIR = "K-State-Data-Contest-2019/K-State-Data-Contest-2019"  #Modified based on my directory
PROJECT_ID = "ipfs"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", PROJECT_ID)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Visualizing Relationships between Cancelled and other predictors
#
# - We want to use our visualizations to determine which predictors might be useful in our model

# %% [markdown]
# ## Percentage of Agents Registered for Cancel List by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentCancelList by Cancelled.png")

# %% [markdown]
# ## Percentage of Agents Enrolled in Credit Program by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentCreditProgram by Cancelled.png")

# %% [markdown]
# ## Percentage of Agents Enrolled in EForms by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentEForms by Cancelled.png")

# %% [markdown]
# ## Percentage of Agents Registered for E-ImpendingReport by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentImpendingReport by Cancelled.png")

# %% [markdown]
# ## Percentage of Agents enrolled in notification of late payment of borrower by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentIntentEForm by Cancelled.png")

# %% [markdown]
# ## Percentage of Agents Registered on Web by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/AgentsRegisteredOnWeb by Cancelled.png")

# %% [markdown]
# ## Percentage Borrowers using Auto Payments by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Autocharge VS Cancelled.png")

# %% [markdown]
# ## Average Dollar Amount Financed by Borrower by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average AmtFin by Cancelled.png")

# %% [markdown]
# ## Average Borrrower Down Payment in Dollars by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average Down Payment by Cancelled.png")

# %% [markdown]
# ## Average Initial monetary risk amount at time of loan issuance by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average exposure by Cancelled.png")

# %% [markdown]
# ## Average Loan Term by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average Loan Term by Cancelled.png")

# %% [markdown]
# ## Average Dollar Amount of NSF Charge in Dollars by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average NSF by Cancelled.png")

# %% [markdown]
# ## Average Insurance Premium Amount in Dollars by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Average Premium by Cancelled.png")

# %% [markdown]
# ## Average Loan APR by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Avg APR by Cancelled.png")

# %% [markdown]
# ## Average Finance Charge in Dollars by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Avg FinChg by Cancelled.png")

# %% [markdown]
# ## Percentage of Loans Cancelled in each Borrower Industry

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Borrower Classification by Cancelled.png")

# %% [markdown]
# ## Percentage of Borrowers Registered for EForms by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Borrower EForms by Cancelled.png")

# %% [markdown]
# ## Percentage of Borrowers Registered for Cancellation Warning by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/BorrowerCancelWarning by Cancelled.png")

# %% [markdown]
# ## Percentage of Borrowers Registered on Web by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/BorrowerWebRegistration by Cancelled.png")

# %% [markdown]
# ## Percentage of Borrowers who Cancelled by their Sub-Industry Classification

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Cancellation by Borrower_SubTerm.png")

# %% [markdown]
# ## Percentage of Loans Cancelled by Borrower State

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Cancellation Rate by Borrower State.png")

# %% [markdown]
# ## Average Default Charge in Dollars by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Default_Charge Vs Cancelled.png")

# %% [markdown]
# ## Percentage of Borrowers who Cancelled by Borrower Credit Score

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/PCT Cancellation rate by Borrower Credit Score.png")

# %% [markdown]
# ## Average Number of Payments Received by Loan Cancelled Y/N

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/Pmt Rcvd by Cancelled.png")

# %% [markdown]
# ## Number of Loans Cancelled divided by Total Loans made for each state

# %%
Image("K-State-Data-Contest-2019/K-State-Data-Contest-2019/images/ipfs/State Propensities to Cancel Loans.png")
